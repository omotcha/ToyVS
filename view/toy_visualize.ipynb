# %%
import os
from configs.config_win import *
from dbutil.dbutil import DBUtil
import nglview
import pickle
dbu = DBUtil()

# %%
example_id = dbu.get_ids_aff_greater_than("results2k", 8.0)[0]
example = dbu.fetch_row_by_index(example_id)
mol = pickle.loads(example[1])
mol

# %%
prot_f = os.path.join(protein_path, "{}.pdb".format(protein_names[0]))
prot_f
# Out:
# 'D:\\AlexYu\\ToyVS\\data\\proteins\\7AMA.pdb'

# %%
view = nglview.show_file(nglview.FileStructure(prot_f), default=False)
view.add_representation('cartoon', selection='protein', color='white')
rdkit = view.add_component(nglview.RdkitStructure(mol), default=False)
rdkit.add_ball_and_stick(color='red')
view
# Out:
# NGLWidget()

# %%
view.render_image()
# Out:
# Image(value=b'', width='99%')
